# %%
from ipywidgets import interact
from ipywidgets.widgets import IntSlider, FloatSlider, Dropdown
from code_P3_A_11 import *

button_init = Button(description="Init", on_click = init)
button_init.on_click(init)
button_init
